# %%
# Baseball case Study

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Load database
df=pd.read_csv('raw.githubusercontent.com_dsrscientist_Data-Science-ML-Capstone-Projects_master_baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#show the top head
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#show to the top tail
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
#show the informations
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#find the null value
df.isnull().sum().sum()
# Out:
# 0

# %%
# count the W (win)value
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
# lets we cheack the column
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#lets check the shape
df.shape
# Out:
# (30, 17)

# %% [markdown]
# # create heatmap

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %%
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df.shape[0]
# Out:
# 30

# %%
df['W']=df['W'].replace(" ", np.nan)
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
import seaborn as sns

# %%
# data visulation
x = sns.countplot(x='W', data=df)
print(df['W'].value_counts())
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
x = sns.countplot(x='W', data=df)
print(df['W'].value_counts())

# %%
x = sns.countplot(x='R', data=df)
print(df['R'].value_counts())
# Out:
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64

# %%
x = sns.countplot(x='AB', data=df)
print(df['AB'].value_counts())
# Out:
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64

# %%
x = sns.countplot(x='H', data=df)
print(df['H'].value_counts())
# Out:
# 1363    2
# 1497    1
# 1386    1
# 1324    1
# 1494    1
# 1486    1
# 1346    1
# 1374    1
# 1361    1
# 1420    1
# 1351    1
# 1382    1
# 1378    1
# 1341    1
# 1462    1
# 1405    1
# 1349    1
# 1379    1
# 1331    1
# 1419    1
# 1495    1
# 1383    1
# 1370    1
# 1397    1
# 1480    1
# 1515    1
# 1381    1
# 1395    1
# 1479    1
# Name: H, dtype: int64

# %%
x = sns.countplot(x='2B', data=df)
print(df['2B'].value_counts())
# Out:
# 272    3
# 260    2
# 289    2
# 278    2
# 277    2
# 274    2
# 288    2
# 300    1
# 292    1
# 251    1
# 236    1
# 265    1
# 295    1
# 257    1
# 243    1
# 262    1
# 279    1
# 294    1
# 246    1
# 308    1
# 303    1
# 263    1
# Name: 2B, dtype: int64

# %%
x = sns.countplot(x='3B', data=df)
print(df['3B'].value_counts())
# Out:
# 27    3
# 39    2
# 49    2
# 17    2
# 32    2
# 26    2
# 42    1
# 48    1
# 37    1
# 18    1
# 40    1
# 13    1
# 34    1
# 30    1
# 21    1
# 46    1
# 22    1
# 44    1
# 33    1
# 20    1
# 19    1
# 29    1
# 36    1
# Name: 3B, dtype: int64

# %%
x = sns.countplot(x='HR', data=df)
print(df['HR'].value_counts())
# Out:
# 136    2
# 167    2
# 177    2
# 139    1
# 137    1
# 148    1
# 154    1
# 187    1
# 130    1
# 100    1
# 120    1
# 145    1
# 171    1
# 140    1
# 198    1
# 146    1
# 156    1
# 176    1
# 230    1
# 172    1
# 161    1
# 217    1
# 212    1
# 232    1
# 151    1
# 141    1
# 186    1
# Name: HR, dtype: int64

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
np.mean(df['W'])
# Out:
# 80.96666666666667

# %%
sns.heatmap(df.isnull(), cmap='cool_r')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
x = df.drop('W', axis=1)

# %%
y = df['W']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (24, 16)

# %%
x_test.shape
# Out:
# (6, 16)

# %%
y_train.shape
# Out:
# (24,)

# %%
y_test.shape
# Out:
# (6,)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 27.94303250666748

# %% [markdown]
# # model saving

# %%
import pickle
filename ="Baseball Case Study.pkl"
pickle.dump(model, open(filename, 'wb'))

# %%
# complete project
